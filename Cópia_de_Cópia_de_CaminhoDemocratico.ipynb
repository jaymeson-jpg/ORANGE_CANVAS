# %% [markdown]
# <a href="https://colab.research.google.com/github/jaymeson-jpg/ORANGE_CANVAS/blob/master/C%C3%B3pia_de_C%C3%B3pia_de_CaminhoDemocratico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from  import 
from PIL import Image
# %matplotlib inline
img = Image.open("/content/pb.jpg")
img.show()
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7F4904C27850>

# %% [markdown]
# # Avançando Lendo Arquivo de Vídeo indexados na WEB
#
# ```
# # Isto está formatado como código
# ```

# %%
# video
from IPython.core.display import HTML
HTML('<iframe src="https://anchor.fm/jose-sanchez580/embed/episodes/NO-PERDEMOS--NO-PERDEREMOS----E-NO-SOMOS-MANS-e1ralf3/a-a8uakks" height="200px" width="400px" frameborder="0" scrolling="no"></iframe>')
# Out:
# <iframe src="https://anchor.fm/jose-sanchez580/embed/episodes/NO-PERDEMOS--NO-PERDEREMOS----E-NO-SOMOS-MANS-e1ralf3/a-a8uakks" height="200px" width="400px" frameborder="0" scrolling="no"></iframe>

# %%
# video
from IPython.core.display import HTML
HTML('<iframe width="400px" height="200px" src="https://www.youtube.com/embed/CZW08FWWFQ0" title="INTERVENÇÃO FEDERAL HOJE" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="400" height="200" src="https://www.youtube.com/embed/CZW08FWWFQ0" title="INTERVENÇÃO FEDERAL HOJE" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
# video
from IPython.core.display import HTML
HTML('<iframe width="400" height="200" src="https://www.youtube.com/embed/2NguiCrIeqA" title="B0LS0NARO - CONTAGEM REGRESSIVA - O QUE VEM AGORA?" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="400" height="200" src="https://www.youtube.com/embed/2NguiCrIeqA" title="B0LS0NARO - CONTAGEM REGRESSIVA - O QUE VEM AGORA?" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
# video
from IPython.core.display import HTML
HTML('<iframe width="400" height="200" src="https://www.youtube.com/embed/a3s9iwue2OY" title="ATENÇÃ0: BOLSONARO GENERAlS ALERTTAM SOBRE G0LPE C0MUNlSTA" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="400" height="200" src="https://www.youtube.com/embed/a3s9iwue2OY" title="ATENÇÃ0: BOLSONARO GENERAlS ALERTTAM SOBRE G0LPE C0MUNlSTA" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
# video
from IPython.core.display import HTML
HTML('<iframe width="400" height="120" src="https://www.youtube.com/embed/a3s9iwue2OY" title="ATENÇÃ0: BOLSONARO GENERAlS ALERTTAM SOBRE G0LPE C0MUNlSTA" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="400" height="120" src="https://www.youtube.com/embed/a3s9iwue2OY" title="ATENÇÃ0: BOLSONARO GENERAlS ALERTTAM SOBRE G0LPE C0MUNlSTA" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
# video
from IPython.core.display import HTML
HTML('<iframe width="400" height="200" src="https://www.youtube.com/embed/3gwIaZoBPZo" title="Desembargador Sebastião Coelho é aplaudido de pé ao reafirmar apoio à prisão de Moraes, do STF,..." frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="400" height="200" src="https://www.youtube.com/embed/3gwIaZoBPZo" title="Desembargador Sebastião Coelho é aplaudido de pé ao reafirmar apoio à prisão de Moraes, do STF,..." frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
# video
from IPython.core.display import HTML
HTML('<iframe width="400" height="200" src="https://www.youtube.com/embed/jTCIA8Vw18U" title="Ministro da Defesa nega duvidar do sistema eleitoral" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="400" height="200" src="https://www.youtube.com/embed/jTCIA8Vw18U" title="Ministro da Defesa nega duvidar do sistema eleitoral" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
# video
from IPython.core.display import HTML
HTML('<iframe width="400" height="200" src="https://www.youtube.com/embed/rQMnLD0Bevo" title="BRAZILIANS REACT TO HARRY STYLES, Falling" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="400" height="200" src="https://www.youtube.com/embed/rQMnLD0Bevo" title="BRAZILIANS REACT TO HARRY STYLES, Falling" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
# video
from IPython.core.display import HTML
HTML('<iframe width="400" height="200" src="https://www.youtube.com/embed/PHeiYDPlUZ0" title="Belas melodias de violão para descansar a mente e acalmar o coração. Fique mais tranquilo e relaxe." frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="400" height="200" src="https://www.youtube.com/embed/PHeiYDPlUZ0" title="Belas melodias de violão para descansar a mente e acalmar o coração. Fique mais tranquilo e relaxe." frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
# video
from IPython.core.display import HTML
HTML('<iframe width="400" height=200" src="https://www.youtube.com/embed/aS6Ob4vsCSA" title="URGENTE: CORONEL DA FORÇA AÉREA EXPLICA COMO OS MILITARES ESTÃO SE PREPARANDO - ainda há esperança" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="400" height=200" src="https://www.youtube.com/embed/aS6Ob4vsCSA" title="URGENTE: CORONEL DA FORÇA AÉREA EXPLICA COMO OS MILITARES ESTÃO SE PREPARANDO - ainda há esperança" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
# video
from IPython.core.display import HTML
HTML('<iframe width="400" height="200" src="https://www.youtube.com/embed/Y6V_uTGwWqE" title="Automação de Tarefas com Python - Nova Ferramenta BotCity" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="400" height="200" src="https://www.youtube.com/embed/Y6V_uTGwWqE" title="Automação de Tarefas com Python - Nova Ferramenta BotCity" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
